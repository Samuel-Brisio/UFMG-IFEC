# %% [markdown]
# # Relatorio

# %% [markdown]
# # Codigo

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def create_mash(L):
    N = L**2
    lsing = np.random.rand(N)
    for i in range(N):
        lsing[i] = 1 if lsing[i] > 0.5 else -1
        
    return lsing

# %%
def vizinhos(L):
    N = L ** 2
    #Define a tabela de vizinhos
    L=int(np.sqrt(N))
    viz = np.zeros((N,4),dtype=np.int16)
    for k in range(N):
        viz[k,0]=k+1
        if (k+1) % L == 0: viz[k,0] = k+1-L
        viz[k,1] = k+L
        if k > (N-L-1): viz[k,1] = k+L-N
        viz[k,2] = k-1
        if (k % L == 0): viz[k,2] = k+L-1
        viz[k,3] = k-L
        if k < L: viz[k,3] = k+N-L
    return viz

# %%
def expos(beta):
    ex = np.zeros(5,dtype=np.float32)
    ex[0]=np.exp(8.0*beta)
    ex[1]=np.exp(4.0*beta)
    ex[2]=1.0
    ex[3]=np.exp(-4.0*beta)
    ex[4]=np.exp(-8.0*beta)
    return ex

# %%
def calc_energy(L, neighbors, S):
    N = L ** 2
    E = 0
    for i in range(N):
        h = S[neighbors[i, 0]] + S[neighbors[i, 1]]
        E -= S[i] * h 
    return E

# %% [markdown]
# # Metropolis

# %%
def metropolis(T, S, neighbors, expoentes):
    for i in range (S.size):
        h = S[neighbors[i, 0]] + S[neighbors[i, 1]] + S[neighbors[i, 2]] + S[neighbors[i, 3]]
        r = np.random.rand()

        if r <= expoentes[int(h*S[i]*0.5 + 2)]:
            S[i] *= -1
    
    return S, neighbors

# %% [markdown]
# # Monte Carlos

# %%
def Monte_Carlos(L, T, Steps : int):
    S = create_mash(L)
    neighbors = vizinhos(L)

    Energys = []
    Energys.append(calc_energy(L, neighbors, S))

    Magnetizacao = []
    Magnetizacao.append(S.sum())

    expoentes = expos(1/T)
    
    for i in range(Steps):
        S, neighbors =  metropolis(T, S, neighbors, expoentes)
        Energys.append(calc_energy(L, neighbors, S))
        Magnetizacao.append(S.sum())
    
    return Energys, Magnetizacao

# %% [markdown]
# # Execucao

# %% [markdown]
# ## L = 32 and T = 1.5

# %%
np.random.seed(0)

L = 32
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 40 and T = 3

# %%
np.random.seed(1)

L = 40
T = 3
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 5000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 50 and T = 0.4

# %%
np.random.seed(2)

L = 50
T = 0.4
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 40 and T = 2.5

# %%
np.random.seed(3)

L = 40
T = 2.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 2

# %%
np.random.seed(4)

L = 60
T = 2
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 2.3

# %%
np.random.seed(5)

L = 60
T = 2.3
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 2.5

# %%
np.random.seed(6)

L = 60
T = 2.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 3

# %%
np.random.seed(7)

L = 60
T = 3
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 4

# %%
np.random.seed(25)

L = 60
T = 4
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 5

# %%
np.random.seed(26)

L = 60
T = 5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 0.3

# %%
np.random.seed(27)

L = 60
T = 0.3
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 0.2

# %%
np.random.seed(28)

L = 60
T = 0.2
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 0.1

# %%
np.random.seed(29)

L = 60
T = 0.1
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 60 and T = 0.05

# %%
np.random.seed(30)

L = 60
T = 0.05
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 150)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 10 and T = 1.5

# %%
np.random.seed(10)

L = 10
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 30 and T = 1.5

# %%
np.random.seed(11)

L = 30
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 50 and T = 0.05

# %%
np.random.seed(12)

L = 50
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 70 and T = 1.5

# %%
np.random.seed(13)

L = 70
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 90 and T = 1.5

# %%
np.random.seed(14)

L = 90
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 110 and T = 1.5

# %%
np.random.seed(15)

L = 110
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 150 and T = 1.5

# %%
np.random.seed(16)

L = 150
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 200 and T = 1.5

# %%
np.random.seed(17)

L = 200
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)

# %% [markdown]
# ## L = 300 and T = 1.5

# %%
np.random.seed(18)

L = 300
T = 1.5
energias = []
magnetizacoes = []
for i in range(5):
    energia, magnetizacao = Monte_Carlos(L, T, 1000)
    energias.append(energia)
    magnetizacoes.append(magnetizacao)

# %%
for energia in energias:
    plt.plot(energia)

plt.show()

# %%
for magneticao in magnetizacoes:
    plt.plot(magneticao)
